# %% [markdown]
# # Scrape Fantasy Football Rankings <a id="return"></a>
#
# 1. [ESPN Superflex Rankings (Top 100 Overall) (Eric Karabell)](#superflex)
#     * https://www.espn.com/fantasy/football/story/_/id/35420010/fantasy-football-superflex-rankings-2023-quarterback-running-back-wide-receiver-tight-end
# 2. [ESPN Expert Mock Draft; 10-Team, PPR](#espnmockdraft)
#     * https://www.espn.com/fantasy/football/story/_/id/35967408/fantasy-football-mock-draft-10-team-ppr
# 3. [ESPN PPR Rankings by Position](#espnpprrankings)
#     * https://www.espn.com/fantasy/football/story/_/id/35425170/fantasy-football-ppr-rankings-2023-quarterback-running-back-wide-receiver-tight-end
# 4. [PFF Dynasty Superflex Rankings](#pffsuperflexrankings)
#     * https://www.pff.com/news/fantasy-football-post-2023-nfl-draft-fantasy-football-dynasty-superflex-rankings
#
# [Return to Top](#return)
#
# * Which sites do I want to hit?
#     * https://www.espn.com/fantasy/football/story/_/id/35425170/fantasy-football-ppr-rankings-2023-quarterback-running-back-wide-receiver-tight-end
#     * https://www.espn.com/fantasy/football/story/_/id/35967408/fantasy-football-mock-draft-10-team-ppr
#     * https://www.espn.com/fantasy/football/story/_/id/35823568/fantasy-football-rankings-2023-nfl-rookies
#     * https://www.espn.com/fantasy/football/story/_/id/35420010/fantasy-football-superflex-rankings-2023-quarterback-running-back-wide-receiver-tight-end
#     * https://www.reddit.com/r/fantasyfootball/comments/zx8cgl/2023_redraft_rankings/
#     * https://www.pff.com/news/fantasy-football-post-2023-nfl-draft-fantasy-football-dynasty-superflex-rankings

# %% [markdown]
# ## Import Packages

# %%
# import needed packages
import numpy as np
import pandas as pd
import json
import os
import re, requests, bs4, csv, datetime
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %% [markdown]
# ## Set User-Defined Fields

# %%
# set ESPN Superflex URL
espn_superflex_url = 'https://www.espn.com/fantasy/football/story/_/id/35420010/fantasy-football-superflex-rankings-2023-quarterback-running-back-wide-receiver-tight-end'

# set ESPN Mock Draft URL
espn_mock_draft_url = 'https://www.espn.com/fantasy/football/story/_/id/35967408/fantasy-football-mock-draft-10-team-ppr'

# set ESPN Mock Draft URL
espn_ppr_rankings_url = 'https://www.espn.com/fantasy/football/story/_/id/35425170/fantasy-football-ppr-rankings-2023-quarterback-running-back-wide-receiver-tight-end'

# set PFF Dynasty Superflex Rankings
pff_dynasty_superflex_rankings_url = 'https://www.pff.com/news/fantasy-football-post-2023-nfl-draft-fantasy-football-dynasty-superflex-rankings'

# %%
# create function to define how to print pandas dataframe
def print_full(pd_df: object):
    
    # set pandas print options
    with pd.option_context('display.max_rows', None
                          ,'display.max_columns', 500
                          ,'display.precision', 3
                          ,'display.colheader_justify', 'center'
                          ):
        
        # print pandas dataframe
        display(pd_df)

# %% [markdown]
# # ESPN Superflex Rankings (Top 100 Overall) (Eric Karabell) <a id="superflex"></a>
#
# [Return to Top](#return)

# %%
# create function to scrape ESPN superflex rankings data
def scrape_espn_superflex_url(url: str):
    
    # create a GET request
    r = requests.get(url)
    
    # parse the HTML code
    soup = bs4.BeautifulSoup(r.content, 'html.parser')

    # find all b tags that contain the superflex rankings data
    content = soup.find_all(['b'])
    
    # create empty list to hold row data for dataframe
    row_data = []
    
    # loop through each b tag, clean up strings, and parse into player name, team nickname, position, position ranking, and overall ranking
    for b in contents:
        
        # check if contents contain 2 elements
        try:
            
            # create single string with b tag contents
            data = str(b.contents[0].string) + str(b.contents[1].string)
            
            # string split to create player name
            player_name = data.split(', ')[0].strip()
            
            # string split to create team nickname
            team_nickname = data.split(', ')[1].split('(')[0].strip()
            
            # string split to create position name
            position = data.split(', ')[1].split('(')[1].split(')')[0].strip()
            
            # string split to create position ranking
            position_rank = re.split(r'(^[^\d]+)', position)[1:][1]
            
            # string split to clean up position name
            position = re.split(r'(^[^\d]+)', position)[1:][0]

            # append to row data
            row_data.append([player_name, team_nickname, position, position_rank])
            
        # else contents have 1 element
        except:
            
            # create single string with b tag contents
            data = str(b.contents[0].string)
            
            # string split to create player name
            player_name = data.split(', ')[0].strip()
            
            # string split to create team nickname
            team_nickname = data.split(', ')[1].split('(')[0].strip()
            
            # string split to create position name
            position = data.split(', ')[1].split('(')[1].split(')')[0].strip()
            
            # string split to create position ranking
            position_rank = re.split(r'(^[^\d]+)', position)[1:][1]
            
            # string split to clean up position name
            position = re.split(r'(^[^\d]+)', position)[1:][0]
            
            # append to row data
            row_data.append([player_name, team_nickname, position, position_rank])
            
    # create dataframe using row_data
    df = pd.DataFrame(row_data, columns = ['player_name', 'team_nickname', 'position', 'position_rank']).reset_index()

    # rename index to overal_rank
    df.rename(columns={'index': 'overall_rank'}, inplace=True)

    # add 1 to overall ranking since index starts at 0; not 1
    df['overall_rank'] = df['overall_rank'] + 1

    # reorder columns
    df = df[['player_name', 'team_nickname', 'position', 'position_rank', 'overall_rank']]
    
    return df

# %%
# run scrape_espn_superflex_url
espn_superflex_df = scrape_espn_superflex_url(espn_superflex_url)

# check dataframe info and first 2 rows
print_full(espn_superflex_df.info())
print_full(espn_superflex_df.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   player_name    100 non-null    object
#  1   team_nickname  100 non-null    object
#  2   position       100 non-null    object
#  3   position_rank  100 non-null    object
#  4   overall_rank   100 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
# None
#     player_name    team_nickname position position_rank  overall_rank
# 0  Patrick Mahomes     Chiefs       QB           1             1
# 1       Josh Allen      Bills       QB           2             2

# %% [markdown]
# # ESPN Expert Mock Draft; 10-Team, PPR <a id="espnmockdraft"></a>
#
# * Tristan H. Cockcroft, Liz Loza, Eric Karabell, Mike Clay, Eric Moody, Kyle Soppe, Stephania Bell, Daniel Dopp, Tyler Fulghum and Matt Bowen
#
# [Return to Top](#return)

# %%
# create function to scrape ESPN Expert Mock Draft
def scrape_espn_mock_draft_url(url: str):
    
    # create a GET request
    r = requests.get(url)

    # parse the HTML code
    soup = bs4.BeautifulSoup(r.content, 'html.parser')
    
    # create empty list to store data for dataframe
    data = []
    
    # find and loop through all p tags
    for p in soup.find_all('p'):
        
        # check for 'pick' and 'QB' in the HTML text to find data I want to parse
        if ('pick' in p.text.lower()) and (p.text.startswith('QB')):

            # string split on ')'
            split_str = p.text.split(')')[:-1]
            
            # remove new line character 
            split_str = [x.replace('\n', '') for x in split_str]
            
            # string split on first number to create position
            position = [re.split(r'(^[^\d]+)', x)[1] for x in split_str]

            # string split on first number and on ',' to create player name
            player_name = [re.split(r'(^[^\d]+)', x)[2].split(',')[0][2:] for x in split_str]

            # string split on first number, on ',' and on '(' to create team short name
            team_short_name = [re.split(r'(^[^\d]+)', x)[2].split(',')[1].split('(')[0].strip() for x in split_str]

            # string split on first number, on ':' and on '.' to create draft round
            draft_rnd = [int(re.split(r'(^[^\d]+)', x)[2].split(':')[1].strip().split('.')[0]) for x in split_str]

            # string split on first number, on ':' and on '.' to create draft pick
            draft_pick = [int(re.split(r'(^[^\d]+)', x)[2].split(':')[1].strip().split('.')[1]) for x in split_str]

            # zip above data and create list of lists
            zipped_data = list(zip(player_name, position, team_short_name, draft_rnd, draft_pick))

            # append each row of data to empty list created above
            for row in zipped_data:
                data.append(row)

    # create dataframe using data
    df = pd.DataFrame(data, columns = ['player_name', 'position', 'team_short_name', 'draft_rnd', 'draft_pick']).sort_values(['draft_rnd', 'draft_pick']).reset_index(drop=True)

    return df

# %%
# run scrape_espn_mock_draft_url
espn_mock_draft_df = scrape_espn_mock_draft_url(espn_mock_draft_url)

# check dataframe info and first 2 rows
print_full(espn_mock_draft_df.info())
print_full(espn_mock_draft_df.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   player_name      160 non-null    object
#  1   position         160 non-null    object
#  2   team_short_name  160 non-null    object
#  3   draft_rnd        160 non-null    int64
#  4   draft_pick       160 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 6.4+ KB
# None
#       player_name      position team_short_name  draft_rnd  draft_pick
# 0  Christian McCaffrey    RB            SF           1           1
# 1     Justin Jefferson    WR           Min           1           2

# %% [markdown]
# # ESPN PPR Rankings by Position <a id="espnpprrankings"></a>
#
# [Return to Top](#return)

# %%
# create function to scrape ESPN PPR Rankings by Position
def scrape_espn_ppr_rankings_url(url: str):
    
    # create a GET request
    r = requests.get(url)

    # parse the HTML code
    soup = bs4.BeautifulSoup(r.content, 'html.parser')
    
    # create empty list to store data for dataframe
    data = []
    
    # create list of positions
    pos_list = ['QB', 'RB', 'WR', 'TE']
    
    # set initial index to 0
    index = 0

    # find and loop through all p tags
    for p in soup.find_all('p'):
        
        # check if the HTML text starts with '1'
        if p.text.startswith('1'):

            # split string on first occuring number to create position rank
            pos_rank = [int(x) for x in re.split(r'(\d+)', p.text) if x.isnumeric()]
            
            # split string on first occuring number and ',' to create player name
            player_name = [x.split(',')[0][2:] for x in re.split(r'(\d+)', p.text) if x.startswith('.')]
            
            # split string on first occuring number and ',' to create city name.  also, replaced newline character
            city_name = [x.split(',')[1].replace('\n', '')[1:] for x in re.split(r'(\d+)', p.text) if x.startswith('.')]

            # zip above data and create list of lists
            zipped_data = list(zip(player_name, [pos_list[index]] * len(player_name), city_name, pos_rank))

            # append each row of data to empty list created above
            for row in zipped_data:
                data.append(row)
                
            # increase index by 1
            index += 1
            
    # create dataframe using data
    df = pd.DataFrame(data, columns = ['player_name', 'position', 'city_name', 'position_rank']).sort_values(['position', 'position_rank']).reset_index(drop=True)

    return df

# %%
# run scrape_espn_ppr_rankings_url
espn_ppr_rankings_df = scrape_espn_ppr_rankings_url(espn_ppr_rankings_url)

# check dataframe info and first 2 rows
print_full(espn_ppr_rankings_df.info())
print_full(espn_ppr_rankings_df.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player_name  207 non-null    object
#  1   position     207 non-null    object
#  2   city_name    207 non-null    object
#  3   pos_rank     207 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 6.6+ KB
# None
#     player_name    position city_name  pos_rank
# 0  Patrick Mahomes    QB         KC        1
# 1       Josh Allen    QB        BUF        2

# %% [markdown]
# # PFF Dynasty Superflex Rankings <a id="pffsuperflexrankings"></a>
#
# [Return to Top](#return)

# %%
# create definition to scrape PFF Dynasty Superflex Rankings
def scrape_pff_dynasty_superflex_rankings_url(url: str):
    
    # create a GET request
    r = requests.get(url)

    # parse the HTML code
    soup = bs4.BeautifulSoup(r.content, 'html.parser')
    
    # create empty list to store data for dataframe
    data = []
    
    # find the tbody tag and all its tr tags
    for tr in soup.find('tbody').find_all('tr'):
        
        # grab all td tags
        tds = tr.find_all('td')
        
        # string split on first number to create position rank
        pos_rank = re.split(r'(\d+)', tds[4].text.strip())
        
        # due to first row being a header row, grab element at first or zero index
        try:

            pos_rank = pos_rank[1]
        except:

            pos_rank = pos_rank[0]
        
        # add text to empty list
        data.append([tds[0].text.strip(), tds[1].text.strip(), tds[2].text.strip(), tds[3].text.strip(), pos_rank])

    # create dataframe using data
    df = pd.DataFrame(data)
    
    # assign first row and dataframe header
    df.columns = ['overall_rank', 'position', 'player_name', 'team_nickname', 'position_rank']
    
    # remove first row
    df = df[1:]
    
    return df

# %%
# run scrape_espn_ppr_rankings_url
pff_dynasty_superflex_rankings_df = scrape_pff_dynasty_superflex_rankings_url(pff_dynasty_superflex_rankings_url)

# check dataframe info and first 2 rows
print_full(pff_dynasty_superflex_rankings_df.info())
print_full(pff_dynasty_superflex_rankings_df.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 1 to 300
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   overall_rank   300 non-null    object
#  1   position       300 non-null    object
#  2   player_name    300 non-null    object
#  3   team_nickname  300 non-null    object
#  4   pos_rank       300 non-null    object
# dtypes: object(5)
# memory usage: 11.8+ KB
# None
#   overall_rank position player_name  team_nickname pos_rank
# 1       1         QB     Jalen Hurts     Eagles        1
# 2       2         QB      Josh Allen      Bills        2

# %%
data = []
counter = 0
for tr in soup.find('tbody').find_all('tr'):
    tds = tr.find_all('td')
    print(tds)
# Out:
# [<td class="first-column">{{ source.name }}</td>, <td>{{ source.projection }}</td>, <td>{{ source.diff }}</td>, <td><a :href="propData.prop.url + '?utm_source=fantasypros.com&amp;utm_medium=referral&amp;utm_campaign=beticon'" target="_blank">{{ source.pick }}</a></td>, <td>{{ source.cover}}</td>]

# %%
# Making a GET request
# r = requests.get('https://www.reddit.com/r/fantasyfootball/comments/zx8cgl/2023_redraft_rankings/')
# r = requests.get('https://www.espn.com/fantasy/football/story/_/id/35425170/fantasy-football-ppr-rankings-2023-quarterback-running-back-wide-receiver-tight-end')
# r = requests.get('https://www.espn.com/fantasy/football/story/_/id/35967408/fantasy-football-mock-draft-10-team-ppr')
# r = requests.get('https://www.espn.com/fantasy/football/story/_/id/35420010/fantasy-football-superflex-rankings-2023-quarterback-running-back-wide-receiver-tight-end')
# r = requests.get('https://www.pff.com/news/fantasy-football-post-2023-nfl-draft-fantasy-football-dynasty-superflex-rankings')
r = requests.get('https://www.fantasypros.com/nfl/rankings/ppr-cheatsheets.php')

# https://thehuddle.com/lists/2023-fantasy-football-ppr-rankings/

 
# Parsing the HTML
soup = bs4.BeautifulSoup(r.content, 'html.parser')
# print(soup.prettify())
# print(soup)

# s = soup.find('p')
# content = soup.find_all('div', class_ = 'article-body')
# content = soup.find('tbody').find_all('tr')
# content = soup.find('table', id="ranking-table")
# content = soup.find('tbody')
content = soup.find_all('div', class_ = 'rankings-app')
# content = soup.find_all('thead')
table = soup.find_all('div', class_ = 'container')
print(table)
# print(soup.prettify())
print(content)
# Out:
# [<div class="container" id="main-container" role="main">
# <div class="main-content-wrap main-content-wrap--rankings-page">
# <div class="main-content main-content--rankings-page" id="rankings-app">
# <div class="banners-wrap">
# <div class="live-draft-banner hide-print" v-cloak="" v-if="liveDraftEnabled">
# <span>Draft Mode is ON</span>
# </div>
# <div class="sleeper-promo live-draft-banner hide-print" v-else="">
# <a class="sleeper-promo--link" href="https://go.slpr.link/FantasyProsWeb" onclick="ga('send', 'event', 'NFL ECR', 'Sleeper Click');" target="_blank">
# <img alt="Draft with Sleeper" class="sleeper-image mobile-image" src="https://images.fantasypros.com/images/promos/sleeper-wsid-promo-780x70.png"/>
# <img alt="Draft with Sleeper" class="sleeper-image desktop-image" src="https://images.fantasypros.com/images/promos/sleeper-wsid-promo-1512x70.png"/></a>
# </div>
# </div>
# <div class="options-overlay" v-cloak="" v-show="breakpoints.show_overlay &amp;&amp; isOverlayEnabled">
# <div class="options-overlay-header">
# <a @click="overlayChangeHandler(false, false)" class="overlay-dismissable overlay-dismissable--cancel">Cancel</a>
# <h3 class="overlay-title">Options
# <a @click="overlayChangeHandler(false, true)" class="overlay-dismissable overlay-dismissable--done">Done</a>
# </h3></div>
# <div class="options-overlay-content">
# <a @click="modalDisplayHandler({target: 'ecr', ga_event: 'upgrade_button'})" class="overlay-premium-cta">Upgrade to Premium ECR for advanced insights</a>
# <label class="overlay-label" for="table-view-options">View</label>
# <div class="select-wrap overlay-select">
# <select @change="tableViewChangeHandler({ selected: $event.target.value, label: $event.target.selectedOptions[0].text })" class="table-view-options" label="Change View">&gt;
#                             <option :key="option.id" :selected="option.id === activeTableView" :value="option.id" v-for="option in tableViewOptions">{{ option.label }}</option>
# </select>
# </div>
# <!-- <label class="overlay-label" for="expert-options">Experts</label>
#                     <div class="select-wrap overlay-select">
#                         <select label="Change selected experts" class="expert-options" @change="expertOptionChangeHandler({ selected: $event.target.value, label: $event.target.selectedOptions[0].text })">
#                             <option v-for="expert in pillsGroupOptions.experts" :value="expert.id" :selected="expert.id === activeExpertSet" :key="expert.id">{{ expert.title }}</option>
#                         </select>
#                     </div> -->
# <div class="mpb-controls__wrapper">
# <template v-if="leagueOptions.length">
# <label for="mpb-controls__select--leagues">League</label>
# <div class="select-wrap overlay-select overlay-mpb-controls">
# <select @change="mpbControlsHandler({type: 'mpb-leagues', selected: $event.target.value})" class="mpb-controls__select mpb-controls__select--leagues">
# <option :key="option.id" :selected="option.id == selectedLeagueInfo.id" :value="option.id" v-for="option in leagueOptions">{{ option.label }}</option>
# </select>
# </div>
# </template>
# <div v-else-if="!leagueOptions.length || !isLoggedIn">
# <label>League</label>
# <a @click="mpbControlsHandler({type: 'mpb-leagues', selected: 'sync', sync_type: 'league' })" aria-label="Sync a new league" class="mpb-sync__button" type="button">New League Sync</a>
# </div>
# <template v-if="teamOptions.length">
# <label for="mpb-controls__select--teams">Teams</label>
# <div class="select-wrap overlay-select overlay-mpb-controls">
# <select @change="mpbControlsHandler({type: 'mpb-teams', selected: $event.target.value})" class="mpb-controls__select mpb-controls__select--teams">
# <option :key="option.id" :selected="option.id == selectedTeamInfo.id" :value="option.id" v-for="option in teamOptions">{{ option.label }}</option>
# </select>
# </div>
# </template>
# <div>
# <label class="mpb-controls__label" for="mpb-controls__buttons--availability">Availability</label>
# <div class="mpb-controls__button-container mpb-controls__button-container--availability">
# <template v-for="option in availabilityOptions">
# <div :key="option.id" class="mpb-controls__button-wrapper" v-if="!option.hide">
# <button :class="['mpb-control__button', `mpb-control__button--${option.id}`, option.class ? option.class : '', liveDraftEnabled ? 'disabled-pointer' : '']" @click="mpbControlsHandler({type: 'mpb-availability', event: $event, id: option.id, value: 'ignore_if_sync'})">
# <input :aria-label="option.aria_label" :checked="option.is_checked" @change="mpbControlsHandler({type: 'mpb-availability', event: $event, id: option.id, value: $event.target.checked})" type="checkbox"/> <span>{{ option.title }}</span>
# </button>
# </div>
# </template>
# </div>
# </div>
# </div>
# <div class="overlay-live-draft">
# <div class="live-draft-toggle__wrapper">
# <label class="overlay-label">Draft Mode</label>
# <fp-toggle :checked="!!liveDraftEnabled" :prevent-default="true" @prevent-toggle-default="liveDraftModeHandler($event)" fp-aria-label="Toggle draft mode" tabindex="0"></fp-toggle>
# </div>
# </div>
# <div class="overlay-button-group">
# <div class="overlay-button-wrap">
# <label class="overlay-label" for="overlay-download__button--csv">Download</label>
# <fp-button :show-icon="true" @btnclicked="csvDownloadHandler($event)" btn-icon="fa-download" class="overlay-download__button overlay-download__button--csv" text="Download CSV" type="tertiary"></fp-button>
# </div>
# <div class="overlay-button-wrap">
# <label class="overlay-label" for="overlay-download__button--print">Printer Friendly</label>
# <fp-button :show-icon="true" @btnclicked="printViewHandler" btn-icon="fa-print" class="overlay-download__button overlay-download__button--print" text="Download PDF" type="tertiary"></fp-button>
# </div>
# </div>
# </div>
# </div>
# <div class="inner">
# <div class="ranking-header-wrap--padding-one-banner">
# <div class="ranking-header-wrap clearfix hide-print">
# <div class="ranking-header">
# <div class="rankings-page__heading-wrap">
# <h1 class="rankings-page__heading">
#                                 Fantasy Football Draft Rankings (2023)                                </h1>
# <h2 class="rankings-page__sub-heading" v-if="false">Consensus Rankings</h2>
# <h2 class="rankings-page__sub-heading" v-cloak="" v-html="pageSubheader"></h2>
# </div>
# <div class="ranking-page__header-button-container hide-print" v-if="displayPickExpertsButton">
# <!-- <a v-if="false" role="button" class="btn btn-primary edit-experts-button">Pick Experts</a> -->
# <button @click="modalIsVisible.pick_experts = true" @close="modalIsVisible.pick_experts = true" aria-label="Open experts modal" class="btn header-btn header-btn--edit-experts">Pick Experts</button>
# <button @click="modalDisplayHandler({target: 'ecr', ga_event: 'upgrade_button'})" aria-label="Open upgrade modal" class="btn header-btn header-btn--upgrade-ecr">Upgrade</button>
# </div>
# </div> <!-- .ranking-header -->
# </div>
# <div class="feature-items__container hide-print">
# <div class="feature-primary feature-primary--live-draft">
# <div class="select-advanced__ecr-wrapper left-side-bar-hidden">
# <div class="select-advanced select-advanced--rankings" v-if="false">
# <span class="select-advanced__select-label select-advanced__select-label--top">Rankings</span>
# <div class="select-advanced__button-container">
# <button class="select-advanced__button" type="button"><span class="select-advanced__button-text">Draft</span> <i aria-hidden="true" class="fa fa-chevron-down"></i></button>
# </div>
# </div>
# <fp-select-advanced :button-label="pillsGroupOptions.rankings[positionId][lastValidScoringTypeUsed][rankingType].label" :data="Object.values(pillsGroupOptions.rankings[positionId][lastValidScoringTypeUsed])" :set-selected="[rankingType]" :show-label="true" @selected-change="tableViewChangeHandler({selected: $event[0]})" class-modifier="select-advanced--ranking" label-text="Rankings" v-cloak=""></fp-select-advanced>
# </div>
# <div class="select-advanced__ecr-wrapper">
# <div class="select-advanced select-advanced--scoring" v-if="false">
# <span class="select-advanced__select-label select-advanced__select-label--top">Scoring</span>
# <div class="select-advanced__button-container">
# <button class="select-advanced__button" type="button"><span class="select-advanced__button-text">PPR</span> <i aria-hidden="true" class="fa fa-chevron-down"></i></button>
# </div>
# </div>
# <fp-select-advanced :button-label="pillsGroupOptions.scoring[scoring].label" :data="Object.values(pillsGroupOptions.scoring)" :set-selected="[scoring]" :show-label="true" @selected-change="rankingOptionChangeHandler({type: 'scoring', selected: $event[0]})" class-modifier="select-advanced--scoring" label-text="Scoring" v-cloak=""></fp-select-advanced>
# </div>
# <div class="select-advanced__ecr-wrapper hidden-overlay">
# <div class="select-advanced select-advanced--view" v-if="false">
# <span class="select-advanced__select-label select-advanced__select-label--top">View</span>
# <div class="select-advanced__button-container">
# <button class="select-advanced__button" type="button"><span class="select-advanced__button-text">Overview</span> <i aria-hidden="true" class="fa fa-chevron-down"></i></button>
# </div>
# </div>
# <fp-select-advanced :button-label="tableViewOptions[activeTableView].label" :data="Object.values(tableViewOptions)" :set-selected="[activeTableView]" :show-label="true" @selected-change="tableViewChangeHandler({selected: $event[0]})" class-modifier="select-advanced--view everything-but-phone" label-text="View" v-cloak=""></fp-select-advanced>
# </div>
# <div class="select-advanced__ecr-wrapper hidden-overlay">
# <div class="select-advanced select-advanced--expert-groups" v-if="false">
# <span class="select-advanced__select-label select-advanced__select-label--top">Experts</span>
# <div class="select-advanced__button-container">
# <button class="select-advanced__button" type="button"><span class="select-advanced__button-text">Latest ECR</span> <i aria-hidden="true" class="fa fa-chevron-down"></i></button>
# </div>
# </div>
# <fp-select-advanced :button-label="activeExpertSetOptions.content" :data="pickExpertsDropdownData" :set-selected="[activeExpertSet]" :show-label="true" class-modifier="select-advanced--expert-groups select-advanced--max-width" label-text="Experts" v-cloak="">
# <template slot="selectAdvancedList">
# <li :class="{ 'select-advanced__item--heading': item.header }" :key="item.id" class="select-advanced__item" v-for="item in pickExpertsDropdownData">
# <div class="select-advanced__item-container" v-if="!item.header">
# <button @click="expertOptionChangeHandler(item)" class="select-advanced__option" type="button">
# <span class="select-advanced__option-selected">
# <i :class="{'selected': activeExpertSet == item.id}" aria-hidden="true" class="fa fa-check"></i>
# </span>
# <div class="select-advanced__option-text-container">
# <div class="select-advanced__option-title" v-html="item.content" v-if="item.content">{{item.content}}</div>
# <div class="select-advanced__option-desc" v-html="item.description" v-if="item.description">{{item.description}}</div>
# </div>
# </button>
# <span class="select-advanced__count" v-if="item.showCount">{{ item.count }}</span>
# </div>
# <div v-else="">{{ item.content }}</div>
# </li>
# <li class="select-advanced__item select-advanced__item--heading">
# <div>Custom Experts</div>
# </li>
# <li class="select-advanced__item">
# <div class="select-advanced__item-container">
# <button @click="modalIsVisible.pick_experts = true" class="select-advanced__option" type="button">
# <span class="select-advanced__option-selected">
# <i aria-hidden="true" class="selected"></i>
# </span>
# <div class="select-advanced__option-text-container">
# <div class="select-advanced__option-title select-advanced__option-title--cta">Click here to pick experts</div>
# </div>
# </button>
# </div>
# </li>
# </template>
# </fp-select-advanced>
# </div>
# <template v-if="!breakpoints.phone">
# <div class="select-advanced__ecr-wrapper hidden-overlay">
# <fp-select-advanced :button-label="selectedLeagueInfo.label" :data="leagueOptions" :set-selected="[selectedLeagueInfo]" :show-label="true" @selected-change="mpbControlsHandler({type: 'mpb-leagues', selected: $event[0]})" class-modifier="select-advanced--mpb-leagues select-advanced--max-width" label-text="Leagues" v-if="leagueOptions.length"></fp-select-advanced>
# <template v-else-if="!leagueOptions.length || !isLoggedIn">
# <div class="select-advanced select-advanced--leagues">
# <span class="mpb-controls__label select-advanced__select-label select-advanced__select-label--top">Leagues</span>
# <div class="select-advanced__button-container">
# <button @click="mpbControlsHandler({type: 'mpb-leagues', selected: 'sync', sync_type: 'league' })" aria-label="Sync a new league" class="select-advanced__button mpb-sync__button" type="button"><span class="select-advanced__button-text"><span class="text-extra">New </span>League Sync</span></button>
# </div>
# </div>
# </template>
# </div>
# <div class="select-advanced__ecr-wrapper hidden-overlay" v-if="teamOptions.length">
# <fp-select-advanced :button-label="selectedTeamInfo.label" :data="teamOptions" :set-selected="[selectedTeamInfo]" :show-label="true" @selected-change="mpbControlsHandler({type: 'mpb-teams', selected: $event[0]})" class-modifier="select-advanced--mpb-teams select-advanced--max-width" label-text="Teams" v-if="teamOptions.length"></fp-select-advanced>
# </div>
# <div class="select-advanced__ecr-wrapper hidden-overlay">
# <div class="select-advanced select-advanced--mpb-availability" v-if="rankingType === 'weekly' &amp;&amp; (breakpoints.show_left_sidebar || (!breakpoints.phone &amp;&amp; !breakpoints.tablet &amp;&amp; !isPremium))">
# <span class="mpb-controls__label select-advanced__select-label select-advanced__select-label--top">Availability</span>
# <div class="mpb-controls__button-container mpb-controls__button-container--availability">
# <template v-for="option in availabilityOptions">
# <div :key="option.id" class="mpb-controls__button-wrapper" v-if="!option.hide">
# <button :class="['mpb-control__button select-advanced__button', `mpb-control__button--${option.id}`, option.class ? option.class : '']" @click="mpbControlsHandler({type: 'mpb-availability', event: $event, id: option.id, value: 'ignore_if_sync'})">
# <input :aria-label="option.aria_label" :checked="option.is_checked" @change="mpbControlsHandler({type: 'mpb-availability', event: $event, id: option.id, value: $event.target.checked})" type="checkbox"/> <span>{{ option.title }}</span>
# </button>
# </div>
# </template>
# </div>
# </div>
# <fp-select-advanced :class-modifier="`select-advanced--mpb-availability select-advanced--availability-dropdown select-advanced ${liveDraftEnabled ? 'select-advanced--disabled-pointer' : ''}`" :data="[]" :show-label="true" button-label="Show" label-text="Availability" v-cloak="" v-else="">
# <template slot="selectAdvancedList">
# <template v-for="item in availabilityOptions">
# <li :class="['select-advanced__item', item.class]" :key="item.id" v-if="!item.hide">
# <div :class="['select-advanced-content select-advanced-content--checkbox', item.class]">
# <input :aria-label="item.aria_label" :checked="item.is_checked" @change="mpbControlsHandler({type: 'mpb-availability', event: $event, id: item.id, value: $event.target.checked})" type="checkbox"/> <span @click="mpbControlsHandler({type: 'mpb-availability', event: $event, id: item.id, value: 'checkbox_sibling', checkbox: $event.target.previousElementSibling})">{{ item.title }}</span>
# </div>
# </li>
# </template>
# </template>
# </fp-select-advanced>
# </div>
# </template>
# <div class="live-draft-toggle__wrapper live-draft-toggle__wrapper--pills-toggle everything-but-phone hidden-overlay" v-if="!breakpoints.phone">
# <label class="live-draft-toggle__label">Draft Mode</label>
# <fp-toggle :checked="!!liveDraftEnabled" :prevent-default="true" @prevent-toggle-default="liveDraftModeHandler($event)" fp-aria-label="Toggle draft mode" tabindex="0"></fp-toggle>
# <section class="live-draft-mode-feature-highlight__wrapper">
# <fp-feature-highlight class="feature-highlight--live-draft-mode" content="Turn on this feature to cross off
#                                         players during your draft. It's like your
#                                         very own digital cheat sheet." identifier="LDM" title="New: Draft Mode!"></fp-feature-highlight>
# </section></div>
# <button @click="modalIsVisible.pick_experts = true" aria-label="Open pick experts modal" class="btn pick-experts__button pick-experts__button--pills-button">Pick Experts</button>
# <button @click="overlayChangeHandler(true)" class="activate-overlay__button"><i class="fa fa-ellipsis-h activate-overlay__icon"></i></button>
# </div>
# <div class="feature-promo" v-if="false"> </div>
# <div class="feature-promo" v-cloak="">
# <span v-show="liveDraftEnabled"><a href="https://draftwizard.fantasypros.com/football/draft-assistant/" rel="nofollow" target="_blank">To automatically sync players and get expert pick advice, try our Draft Assistant!</a></span>
# <span id="category-ticker" v-show="!liveDraftEnabled"></span>
# </div>
# <div class="pills-wrap feature-secondary">
# <ul class="pills pills--position">
# <li class="position__li active" v-if="false">
# <a href="javascript:;">Overall</a>
# </li>
# <li class="position__li" v-if="false">
# <a href="javascript:;">QB</a>
# </li>
# <li class="position__li" v-if="false">
# <a href="javascript:;">RB</a>
# </li>
# <li class="position__li" v-if="false">
# <a href="javascript:;">WR</a>
# </li>
# <li class="position__li" v-if="false">
# <a href="javascript:;">TE</a>
# </li>
# <li class="position__li" v-if="false">
# <a href="javascript:;">K</a>
# </li>
# <li class="position__li" v-if="false">
# <a href="javascript:;">DST</a>
# </li>
# <li class="position__li" v-if="false">
# <a href="javascript:;">FLEX</a>
# </li>
# <template v-cloak="" v-for="option in pillsGroupOptions.positions">
# <li :class="[{'active': positionId == option.id}, 'position__li']" v-if="!option.extra_all &amp;&amp; !(option.extra_mobile &amp;&amp; breakpoints.phone)">
# <a @click="rankingOptionChangeHandler({type: 'positionId', selected: option.id})" href="javascript:;">{{ option.title }}</a>
# </li>
# </template>
# <li class="position__li position__li--more select-wrap__pills select-wrap__pills--show-all">
# <select @change="rankingOptionChangeHandler({type: 'positionId', selected: $event.target.value, resize: 'more-position-select'})" aria-label="Select from additional positions" class="position-pills__select" id="more-position-select" v-cloak="">
# <option disabled="" selected="" value="">More</option>
# <template v-for="option in pillsGroupOptions.positions">
# <option :selected="positionId == option.id" :value="option.id" v-if="option.extra_all || (option.extra_mobile &amp;&amp; breakpoints.phone)">{{ option.title }}</option>
# </template>
# </select>
# </li>
# </ul>
# <div class="option-icons__container">
# <button @click="csvDownloadHandler($event)" aria-label="Download CSV file" class="option-icon__button-wrap"><i class="fa fa-download option-icon"></i></button>
# <button @click="printViewHandler" aria-label="Open print view" class="option-icon__button-wrap"><i class="fa fa-print option-icon"></i></button>
# </div>
# </div>
# </div>
# <rankings-table :display-all-rows="false" :is-loading="isLoadingRankingsTable" :is-phone="breakpoints.phone" :is-premium="isPremium" :live-draft-mode="liveDraftEnabled" :notes="noteData" :position="positionId" :ranking-type="rankingType" :rankings="playerRankings" :scoring="scoring" :stats="playerStats" :table-view="activeTableView" @modal-display-handler="modalDisplayHandler" ref="rankingstable"></rankings-table>
# </div>
# <div class="table-footer-info">
# <p>
#                         "Latest Update" refers to when we last checked for revised rankings.
#                         Please note that we have no control over how frequently the experts update their rankings.
#                         The publish date is provided for each expert to give you an idea of how fresh their rankings are.
#                     </p>
# <p>
#                         Injury Alerts: Q = Questionable, O = Out, IR = Injured Reserve, S = Suspension
#                     </p>
# </div>
# <fp-modal :show="modalIsVisible.live_draft" @close="modalIsVisible.live_draft = false" class="rankings-modal rankings-modal--live-draft" size="small" v-if="modalIsVisible.live_draft">
# <template v-slot:header="">
# <button @click="modalIsVisible.live_draft = false" aria-label="Close draft modal" class="modal-header__close modal-header__close--live-draft" role="button"></button>
# <h4 class="modal-header__title modal-header__title--live-draft">DRAFT MODE</h4>
# </template>
# <template v-slot:content="">
# <div class="clearfix modal-content__wrapper">
# <p class="modal-content__text modal-content__text--live-draft">
#                             Cross off drafted players during your draft directly from within ECR. To enable draft mode, create a FREE account, it only takes a few seconds. <a :href="secureRedirect('login')">Already have an account? Click here to Log In.</a>
# </p>
# </div>
# </template>
# <template v-slot:footer="">
# <div class="clearfix modal-link__wrapper modal-link__wrapper--live-draft">
# <button @click="modalIsVisible.live_draft = false" class="modal-dismiss__button" role="button">Cancel</button>
# <a :href="secureRedirect('register')" class="btn modal-cta__button">CREATE FREE ACCOUNT</a>
# </div>
# </template>
# </fp-modal>
# <fp-modal :full-width-on-mobile="false" :show="modalIsVisible.prop_bet" @close="modalIsVisible.prop_bet = false" class="prop-bet-modal" size="small" v-if="modalIsVisible.prop_bet">
# <template v-slot:header="">
# <button @click="modalIsVisible.prop_bet = false" aria-label="Close player prop modal" class="prop-bet-modal__close-button" role="button"></button>
# <div class="prop-bet-modal__header">
# <div class="prop-bet-modal__player-info">
# <img :src="`//images.fantasypros.com/images/players/nfl/${propData.player.player_id}/headshot/210x210.png`" class="prop-bet-modal__player-image"/>
# <div class="prop-bet-modal__player-text">
# <div><span class="bold-text">{{ propData.player.name }}</span> {{ propData.player.position_team }}</div>
# <div>{{ propData.player.matchup }}</div>
# </div>
# </div>
# <div class="prop-bet-modal__top-prop">
# <img src="//images.fantasypros.com/images/icons/top-prop-fire.png"/>
# <div class="prop-bet-header__text">
# <div>TOP</div>
# <div>PROP</div>
# </div>
# </div>
# </div>
# </template>
# <template v-slot:content="">
# <div class="prop-bet-modal__content">
# <h4 class="prop-bet-modal__label">{{ propData.prop.label }}</h4>
# <!-- <div class="mobile-table"> -->
# <table class="table prop-bet-modal__table">
# <thead>
# <tr>
# <th class="first-column">Source</th>
# <th>Projection</th>
# <th>Diff</th>
# <th>Pick</th>
# <th>Prob</th>
# </tr>
# </thead>
# <tbody>
# <tr :key="s" v-for="(source, s) in propData.prop.sources">
# <td class="first-column">{{ source.name }}</td>
# <td>{{ source.projection }}</td>
# <td>{{ source.diff }}</td>
# <td><a :href="propData.prop.url + '?utm_source=fantasypros.com&amp;utm_medium=referral&amp;utm_campaign=beticon'" target="_blank">{{ source.pick }}</a></td>
# <td>{{ source.cover}}</td>
# </tr>
# </tbody>
# </table>
# <!-- </div> -->
# </div>
# </template>
# <template v-slot:footer="">
# <div class="prop-bet-modal__footer">
# <a :href="propData.prop.url + '?utm_source=fantasypros.com&amp;utm_medium=referral&amp;utm_campaign=beticon'" @click="propData.ga('View Analysis Click')" class="prop-bet-modal__button prop-bet-modal__button--analysis" role="button" target="_blank">View Analysis</a>
# <a @click="propData.ga('More Props Click')" class="prop-bet-modal__button prop-bet-modal__button--view-more" href="https://bettingpros.com/nfl/picks/prop-bets/?utm_source=fantasypros.com&amp;utm_medium=referral&amp;utm_campaign=beticon" role="button" target="_blank">More Props</a>
# <div class="prop-bet-modal__bp-promo prop-bet-modal__bp-promo--button-row">
# <span class="prop-bet-modal__bp-text">Powered by</span>
# <a @click="propData.ga('BettingPros Click')" class="prop-bet-modal__bp-link" href="https://www.bettingpros.com?utm_source=fantasypros.com&amp;utm_medium=referral&amp;utm_campaign=beticon" target="_blank"><img class="prop-bet-modal__bp-image" src="https://www.bettingpros.com/assets/images/logo-blue@3x.png"/></a>
# </div>
# </div>
# <div class="prop-bet-modal__bp-promo prop-bet-modal__bp-promo--own-row">
# <span class="prop-bet-modal__bp-text">Powered by</span>
# <a @click="propData.ga('BettingPros Click')" class="prop-bet-modal__bp-link" href="https://www.bettingpros.com?utm_source=fantasypros.com&amp;utm_medium=referral&amp;utm_campaign=beticon" target="_blank"><img class="prop-bet-modal__bp-image" src="https://www.bettingpros.com/assets/images/logo-blue@3x.png"/></a>
# </div>
# </template>
# </fp-modal>
# <fp-feature-modal :cta-button-text="featureModalSettings.cta_button_text" :cta-link="featureModalSettings.cta_link" :description="featureModalSettings.description" :ga-event="featureModalSettings.ga_event" :is-premium-feature="featureModalSettings.is_premium" :learn-more-link="featureModalSettings.learn_more_link" :list-items="featureModalSettings.list_items" :screenshot-url="featureModalSettings.screenshot" :show="modalIsVisible.feature" :title="featureModalSettings.title" @close-modal-handler="modalIsVisible.feature = false" class="rankings-modal" size="custom" v-if="modalIsVisible.feature"></fp-feature-modal>
# <fp-experts-modal :allow-single-expert="isPremium ? 'default' : []" :feed-data="expertGroupsData" :is-logged-in="isLoggedIn" :modal-visible="modalIsVisible.pick_experts" :position="positionId" @close="modalIsVisible.pick_experts = false" @set-selected-experts="selectedExpertsChangeHandler" ref="pickexpertsmodal" v-cloak=""></fp-experts-modal>
# </div> <!-- /.inner -->
# </div> <!-- /#rankings-app .main-content -->
# <nav aria-label="Section-specific" class="featured-nav">
# <section class="featured-nav__nav"><div class="featured-nav__heading"><a class="featured-nav__heading-link" href="/nfl/rankings/ppr-flex.php">NFL Rankings</a></div><ul class="featured-nav__list"><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/ppr-flex.php">
# <span class="item-title">Weekly Rankings</span></a><ul class="featured-nav__list featured-nav__list--child"><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-std"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/flex.php">Standard</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-ppr"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/ppr-flex.php">PPR</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-half"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/half-point-ppr-flex.php">Half PPR</a></li></ul></li><li class="featured-nav__list-item active active--child-is-active"><a class="featured-nav__link" href="/nfl/rankings/ppr-cheatsheets.php">
# <span class="item-title">Draft Rankings</span></a><ul class="featured-nav__list featured-nav__list--child"><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-std"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/consensus-cheatsheets.php">Standard</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-ppr active"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/ppr-cheatsheets.php">PPR</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-half"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/half-point-ppr-cheatsheets.php">Half PPR</a></li><li class="featured-nav__list-item featured-nav__list-item--child"><a class="featured-nav__link featured-nav__link--child" href="/nfl/adp/ppr-overall.php">ADP</a></li></ul></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/ros-ppr-overall.php">
# <span class="item-title">Rest of Season Rankings</span></a><ul class="featured-nav__list featured-nav__list--child"><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-std"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/ros-overall.php">Standard</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-ppr"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/ros-ppr-overall.php">PPR</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-half"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/ros-half-point-ppr-overall.php">Half PPR</a></li></ul></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/dynasty-overall.php">
# <span class="item-title">Dynasty Rankings</span></a><ul class="featured-nav__list featured-nav__list--child"><li class="featured-nav__list-item featured-nav__list-item--child"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/dynasty-overall.php">PPR</a></li><li class="featured-nav__list-item featured-nav__list-item--child"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/dynasty-rookies-overall.php">Rookies</a></li></ul></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/best-ball-overall.php">
# <span class="item-title">Best Ball Rankings</span></a><ul class="featured-nav__list featured-nav__list--child"><li class="featured-nav__list-item featured-nav__list-item--child"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/best-ball-overall.php">Consensus</a></li><li class="featured-nav__list-item featured-nav__list-item--child"><a class="featured-nav__link featured-nav__link--child" href="/nfl/adp/best-ball-overall.php">ADP</a></li></ul></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/waiver-wire-ppr-overall.php">
# <span class="item-title">Waiver Wire Rankings</span></a><ul class="featured-nav__list featured-nav__list--child"><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-std"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/waiver-wire-overall.php">Standard</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-ppr"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/waiver-wire-ppr-overall.php">PPR</a></li><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-half"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/waiver-wire-half-point-ppr-overall.php">Half PPR</a></li></ul></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/devy-overall.php">
# <span class="item-title">Devy Rankings</span></a><ul class="featured-nav__list featured-nav__list--child"><li class="featured-nav__list-item featured-nav__list-item--child js-scoring-half"><a class="featured-nav__link featured-nav__link--child" href="/nfl/rankings/devy-overall.php">Half PPR</a></li></ul></li></ul></section><section class="featured-nav__nav"><div class="featured-nav__heading"><a class="featured-nav__heading-link fp-icon-" href="https://draftwizard.fantasypros.com/football/mock-draft-simulator/">Draft Tools</a></div><ul class="featured-nav__list"><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://draftwizard.fantasypros.com/football/mock-draft-simulator/">
# <span class="item-title">Draft Simulator</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://draftwizard.fantasypros.com/football/mock-drafts/lobby/">
# <span class="item-title">Mock Draft Lobby</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://draftwizard.fantasypros.com/football/draft-assistant/">
# <span class="item-title">Draft Assistant</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://draftwizard.fantasypros.com/football/cheat-sheets/">
# <span class="item-title">Cheat Sheet Creator</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://draftwizard.fantasypros.com/football/draft-software/">
# <span class="item-title">Draft Software</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/auction-values/calculator.php">
# <span class="item-title">Salary Cap Calculator</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://draftwizard.fantasypros.com/football/auction-draft-simulator/">
# <span class="item-title">Salary Cap Simulator</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/perfectdraft/">
# <span class="item-title">Perfect Draft Challenge</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/draft/">
# <span class="item-title">Who Should I Draft?</span></a></li></ul></section><section class="featured-nav__nav"><div class="featured-nav__heading"><a class="featured-nav__heading-link fp-icon-" href="/nfl/rankings/consensus-cheatsheets.php">Draft Research</a></div><ul class="featured-nav__list"><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/consensus-cheatsheets.php">
# <span class="item-title">2023 Rankings</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/dynasty-rookies-overall.php">
# <span class="item-title">Rookie Rankings</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/dynasty-overall.php">
# <span class="item-title">Dynasty Rankings</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/2023-nfl-draft-guide/">
# <span class="item-title">NFL Draft Guide</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/fantasy-football-dynasty-draft-kit/">
# <span class="item-title">Dynasty Draft Kit</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/fantasy-football-best-ball-draft-kit/">
# <span class="item-title">Best Ball Guide</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/adp/overall.php">
# <span class="item-title">ADP Consensus</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/fantasy-football-rankings.php">
# <span class="item-title">FP Experts</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/projections/qb.php">
# <span class="item-title">Projections</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/ffpc/">
# <span class="item-title">FantasyPros Championship</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/rb-sleepers.php">
# <span class="item-title">Sleeper Rankings</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/bye-week-cheatsheet.php">
# <span class="item-title">Bye Week Cheat Sheet</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/rankings/">
# <span class="item-title">Expert Directory</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/strength-of-schedule.php">
# <span class="item-title">Strength of Schedule</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/reports/snap-counts/">
# <span class="item-title">Snap Counts</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/nfl/reports/targets/">
# <span class="item-title">Target Leaders</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="/podcast/">
# <span class="item-title">Podcast</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://discord.gg/RJU29tPrrq" target="_blank">
# <span class="item-title">Fantasy Chat</span></a></li><li class="featured-nav__list-item"><a class="featured-nav__link" href="https://forum.fantasypros.com/" target="_blank">
# <span class="item-title">Forums</span></a></li></ul></section>
# <div class="ad-160 js-ad-slot">
# <div id="div-gpt-ad-1349066428961-7" style="width:160px;">
# <script defer="" type="text/javascript">
# googletag.cmd.push(function() {
# googletag.display('div-gpt-ad-1349066428961-7');
#  });
# </script>
# </div>
# </div>
# </nav> <!-- /.featured-nav -->
# <div class="side-content">
# <div class="side-content side-content__wrapper" id="side-content-app">
# <div class="ad-300 js-ad-slot side-content__ad"> <div id="div-gpt-ad-1349068144086-9" style="width:300px;">
# <script defer="" type="text/javascript">
# googletag.cmd.push(function() {
# googletag.display('div-gpt-ad-1349068144086-9');
#  });
# </script>
# </div>
# </div><script type="text/javascript">var sideContentOffers = {"title":"Go Premium For FREE","initialItems":[{"code":"sub-dksportsbook-hof","partner":"DraftKings Sportsbook","source":"dksportsbook","img":"dk_sportsbook_129x86","alt_text":"DraftKings Sportsbook","locales":["AZ","CO","IN","IA","IL","KS","LA","MD","MI","NH","NJ","OH","OR","PA","VA","WY"],"wager":false,"hidden":false,"plan":"goat","url":"\/plans-free\/?options=dksportsbook"},{"code":"sub-fdsportsbook-hof","partner":"FanDuel Sportsbook","source":"fdsportsbook","img":"fdsportsbook_252x72","alt_text":"FanDuel Sportsbook","locales":["AZ","CO","CT","IA","IL","IN","KS","LA","MI","NY","NJ","OH","PA","TN","VA","WY"],"wager":false,"hidden":false,"plan":"goat","url":"\/plans-free\/?options=fdsportsbook"},{"code":"sub-betmgm-hof","partner":"BetMGM","source":"betmgm","img":"betmgm-offer-logo_250x86","alt_text":"BetMGM.com","locales":["AZ","CO","DC","IN","IA","IL","KS","LA","MI","MS","NJ","OH","PA","TN","VA","WY"],"wager":true,"hidden":false,"plan":"goat","url":"\/plans-free\/?options=betmgm"},{"code":"sub-fd-hof","partner":"FanDuel","source":"fanduel","img":"fanduel-offer-logo_314x60","alt_text":"FanDuel.com","locales":["AK","AL","AS","CA","DC","DE","FL","GA","GU","KY","MA","MD","ME","MN","MO","MP","MS","NA","NC","ND","NE","NH","NM","OK","OR","PR","RI","SC","SD","TX","UT","VI","VT","WI","CAN","NU","NT","PE","NL","NB","NS","MB","SK","QC","AB","ALL"],"wager":false,"hidden":false,"plan":"hof","url":"\/plans-free\/?options=fanduel"},{"code":"sub-jackpot-hof","partner":"Jackpot","source":"jackpot","img":"Jackpot-logo_150x75","alt_text":"jackpot.com","locales":["TX"],"wager":false,"hidden":false,"plan":"hof","url":"\/plans-free\/?options=jackpot"},{"code":"sub-dk-hof","partner":"DraftKings","source":"draftkings","img":"DraftKings_FC_166x86","alt_text":"DraftKings.com","locales":["AK","AL","AS","CA","CT","DC","DE","FL","GA","GU","KY","MA","ME","MN","MO","MP","MS","NA","NC","ND","NE","NM","NY","OK","PR","RI","SC","SD","TX","UT","VI","VT","WI","CAN","NU","NT","PE","NL","NB","NS","MB","SK","AB","ALL"],"wager":false,"hidden":false,"plan":"hof","url":"\/plans-free\/?options=draftkings"}],"items":[],"subtitle":"Deposit at least $10 at a DFS partner site you have NOT played at and get up to a FREE 6 Month\n    HOF Subscription!"};
#
# </script>
# <premium-offers></premium-offers><script type="text/javascript">var sideContentPlayerNews = {"nfl":{"sport":"nfl","news":{"1":{"player_id":"18397","title":"Foster Moreau inks contract with New Orleans","news_url":"\/nfl\/news\/401187\/foster-moreau-inks-contract-with-new-orleans.php","updated":"2023-05-11 00:07:04","player_name":"Foster Moreau","rest_of_title":"Inks contract with New Orleans"},"2":{"player_id":"19587","title":"Lynn Bowden released by Patriots Wednesday ","news_url":"\/nfl\/news\/401186\/lynn-bowden-release-by-patriots-wednesday.php","updated":"2023-05-11 00:02:46","player_name":"Lynn Bowden Jr.","rest_of_title":"Lynn Bowden released by Patriots Wednesday"},"3":{"player_id":"13960","title":"Tyler Kroft signs with the Dolphins Tuesday ","news_url":"\/nfl\/news\/401057\/tyler-kroft-signs-with-dolphins-tuesday.php","updated":"2023-05-09 16:27:31","player_name":"Tyler Kroft","rest_of_title":"Signs with the Dolphins Tuesday"},"4":{"player_id":"14033","title":"Cam Erving inks deal with Carolina Tuesday ","news_url":"\/nfl\/news\/401056\/cam-erving-inks-deal-with-carolina-tuesday.php","updated":"2023-05-09 16:25:02","player_name":"Cameron Erving","rest_of_title":"Cam Erving inks deal with Carolina Tuesday"},"5":{"player_id":"18185","title":"John Wolford signs with Tampa Bay Tuesday ","news_url":"\/nfl\/news\/401055\/john-wolford-signs-with-tampa-bay-tuesday.php","updated":"2023-05-09 16:22:59","player_name":"John Wolford","rest_of_title":"Signs with Tampa Bay Tuesday"},"6":{"player_id":"10845","title":"Kareem Jackson re-signs with Denver Broncos","news_url":"\/nfl\/news\/400990\/kareem-jackson-re-signs-with-denver-broncos.php","updated":"2023-05-08 23:07:12","player_name":"Kareem Jackson","rest_of_title":"Re-signs with Denver Broncos"},"7":{"player_id":"17628","title":"Tre Flowers signs with Atlanta Falcons","news_url":"\/nfl\/news\/400989\/tre-flowers-signs-with-atlanta-falcons.php","updated":"2023-05-08 22:45:06","player_name":"Tre Flowers","rest_of_title":"Signs with Atlanta Falcons"},"8":{"player_id":"11176","title":"Nick Foles released by Indianapolis Colts","news_url":"\/nfl\/news\/400654\/nick-foles-released-by-colts.php","updated":"2023-05-06 00:49:57","player_name":"Nick Foles","rest_of_title":"Released by Indianapolis Colts"},"9":{"player_id":"9907","title":"Andy Dalton to begin season as Panthers' starter","news_url":"\/nfl\/news\/400653\/andy-dalton-to-begin-season-panthers-starter.php","updated":"2023-05-06 00:41:38","player_name":"Andy Dalton","rest_of_title":"To begin season as Panthers' starter"},"10":{"player_id":"17143","title":"Dan Arnold signs with Philadelphia Eagles","news_url":"\/nfl\/news\/400536\/dan-arnold-signs-with-philadelphia-eagles.php","updated":"2023-05-04 21:07:01","player_name":"Dan Arnold","rest_of_title":"Signs with Philadelphia Eagles"},"11":{"player_id":"18211","title":"Dexter Lawrence II signs four-year extension","news_url":"\/nfl\/news\/400535\/dexter-lawrence-ii-signs-four-year-extension.php","updated":"2023-05-04 20:49:01","player_name":"Dexter Lawrence II","rest_of_title":"Signs four-year extension"},"12":{"player_id":"18323","title":"Brett Rypien inks one-year deal with the Rams","news_url":"\/nfl\/news\/400515\/brett-rypien-inks-one-year-deal-with-rams.php","updated":"2023-05-04 18:53:30","player_name":"Brett Rypien","rest_of_title":"Inks one-year deal with the Rams"},"13":{"player_id":"19797","title":"Brock Purdy expected to resume throwing in June","news_url":"\/nfl\/news\/400514\/brock-purdy-expected-to-be-able-to-throw-june.php","updated":"2023-05-04 18:50:41","player_name":"Brock Purdy","rest_of_title":"Expected to resume throwing in June"},"14":{"player_id":"24703","title":"Jalen Carter and Eagles agree to terms Thursday ","news_url":"\/nfl\/news\/400513\/jalen-carter-eagles-agree-to-terms-thursday.php","updated":"2023-05-04 18:47:45","player_name":"Jalen Carter","rest_of_title":"And Eagles agree to terms Thursday"}}},"mlb":{"sport":"mlb","news":{"1":{"player_id":"7 ...
# </script>
# <player-news></player-news><div class="ad-300 js-ad-slot side-content__ad"> <div id="div-gpt-ad-1349068144086-10" style="width:300px;">
# <script defer="" type="text/javascript">
# googletag.cmd.push(function() {
# googletag.display('div-gpt-ad-1349068144086-10');
#  });
# </script>
# </div>
# </div><script type="text/javascript">var sideContentConsensusRankings = {"nfl":{"rankings_url":"\/rankings\/consensus-cheatseets.php","rankings_text":"View All Rankings","sport":"nfl","rankings":[{"player_id":16393,"player_name":"Christian McCaffrey","team_id":"SF","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/christian-mccaffrey.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/16393\/headshot\/210x210.png","rank_ecr":1},{"player_id":19217,"player_name":"Jonathan Taylor","team_id":"IND","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/jonathan-taylor.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/19217\/headshot\/210x210.png","rank_ecr":2,"riser":false,"faller":false},{"player_id":23133,"player_name":"Bijan Robinson","team_id":"ATL","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/bijan-robinson.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/23133\/headshot\/210x210.png","rank_ecr":3,"riser":false,"faller":false},{"player_id":17240,"player_name":"Saquon Barkley","team_id":"NYG","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/saquon-barkley.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/17240\/headshot\/210x210.png","rank_ecr":4,"riser":false,"faller":false},{"player_id":16483,"player_name":"Austin Ekeler","team_id":"LAC","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/austin-ekeler.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/16483\/headshot\/210x210.png","rank_ecr":5,"riser":false,"faller":false},{"player_id":17246,"player_name":"Nick Chubb","team_id":"CLE","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/nick-chubb.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/17246\/headshot\/210x210.png","rank_ecr":6,"riser":false,"faller":false},{"player_id":18269,"player_name":"Josh Jacobs","team_id":"LV","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/josh-jacobs.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/18269\/headshot\/210x210.png","rank_ecr":7,"riser":false,"faller":false},{"player_id":18705,"player_name":"Tony Pollard","team_id":"DAL","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/tony-pollard.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/18705\/headshot\/210x210.png","rank_ecr":8,"riser":false,"faller":false},{"player_id":15514,"player_name":"Derrick Henry","team_id":"TEN","position_id":"RB","url":"https:\/\/www.fantasypros.com\/nfl\/players\/derrick-henry.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/15514\/headshot\/210x210.png","rank_ecr":9,"riser":false,"faller":false},{"player_id":19236,"player_name":"Justin Jefferson","team_id":"MIN","position_id":"WR","url":"https:\/\/www.fantasypros.com\/nfl\/players\/justin-jefferson.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/19236\/headshot\/210x210.png","rank_ecr":10,"riser":false,"faller":false},{"player_id":11594,"player_name":"Travis Kelce","team_id":"KC","position_id":"TE","url":"https:\/\/www.fantasypros.com\/nfl\/players\/travis-kelce.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/11594\/headshot\/210x210.png","rank_ecr":11,"riser":false,"faller":false},{"player_id":19788,"player_name":"Ja'Marr Chase","team_id":"CIN","position_id":"WR","url":"https:\/\/www.fantasypros.com\/nfl\/players\/jamarr-chase.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/19788\/headshot\/210x210.png","rank_ecr":12,"riser":false,"faller":false},{"player_id":16433,"player_name":"Cooper Kupp","team_id":"LAR","position_id":"WR","url":"https:\/\/www.fantasypros.com\/nfl\/players\/cooper-kupp.php","image_url":"https:\/\/images.fantasypros.com\/images\/players\/nfl\/16433\/headshot\/210x210.png","rank_ec ...
# </script>
# <consensus-rankings></consensus-rankings><script type="text/javascript">var sideContentPodcastModule = {"sport":"ALL","totalPodcastCount":1968,"podcastCount":6,"start":0,"limit":"6","nextPodcast":6,"podcasts":[{"content_sport":"MLB","title":"MLB: Leading Off May 10th, 2023 (Ep. 666)","content":"What the Pfaadt? Casey Schmitt's first big league bomb, Bieber rolls on despite the hate, plus Joe and Welsh have PrizePicks, best bets and DFS plays.\n\nShow Starts - 0:00:01\nWhat the Pfaadt? - 0:00:32\nNo Max - 0:03:26\nShane Bieber - 0:06:20\nMason Miller's elbow - 0:9:12\nJose Miranda sent down - 0:10:40\nInjuries - 0:14:25\n3 Up and 3 Down - 0:20:16\nPrizePicks - 0:21:48\nBest Bets - 0:24:22 \nSorare - 0:27:28\nDFS - 0:28:01\nHome Run calls - 0:28:31\n\nFantasyPros Leading Off each and every weekday, presented by PrizePicks The easiest and fastest way to play Daily Fantasy Sports. Pick over or under on player props to win up to 25X your money! Use the Promo code LEADINGOFF when you sign up and they'll match your first deposit up to $100","teaser":"What the Pfaadt? Casey Schmitt's first big league bomb, Bieber rolls on despite the hate, plus Joe and Welsh have PrizePicks, best bets and DFS plays.\n\nShow Starts - 0:00:01\nWhat the Pfaadt? - 0:00:32\nNo Max - 0:03:26\nShane Bieber - 0:06:20\nMason Miller's elbow - 0:9:12\nJose Miranda sent down - 0:10:40\nInjuries - 0:14:25\n3 Up and 3 Down - 0:20:16\nPrizePicks - 0:21:48\nBest Bets - 0:24:22 \nSorare - ","url":"https:\/\/soundcloud.com\/fantasypros-baseball-podcast\/mlb-leading-off-may-10th-2023-ep-666","published":"2023-05-10 17:53:05","timestamp":1683741185,"duration":"00:30:34","author":"FantasyPros Baseball Podcast","author_url":"https:\/\/podcasts.apple.com\/us\/podcast\/fantasypros-fantasy-baseball-podcast\/id1099324246?mt=2&ls=1","full_img":"\/\/images.fantasypros.com\/images\/logos\/fp-baseball-podcast-500x500.jpg","stars":"5","ratings":"1,100"},{"content_sport":"NFL","title":"Risk vs. Reward: Are We Taking These 12 High-Upside Players? (Ep. 1072)","content":"<p>Join Joe Pisapia and Derek Brown as they evaluate 12 high-upside players for the upcoming season and highlight their potential for success or failure in the upcoming season. Is it smart to take Kenneth Walker as a top-12 RB this season? The Pros will tell you!<\/p> <p>Timestamps:<\/p> <p>Introduction - 0:00:01<br \/> Breece Hall - 0:00:39<br \/> Ken Walker - 0:02:52<br \/> Travis Etienne - 0:06:06<br \/> J.K. Dobbins - 0:08:25<br \/> Dalvin Cook - 0:11:27<br \/> FantasyPros Dynasty Football Podcast - 0:14:36<br \/> Keenan Allen - 0:15:04<br \/> Deebo Samuel - 0:17:23<br \/> DJ Moore - 0:19:51<br \/> DeAndre Hopkins - 0:22:37<br \/> Anthony Richardson\/Deshaun Watson - 0:24:26<br \/> Kyle Pitts - 0:27:14<br \/> Closing - 0:29:48<\/p>","teaser":"<p>Join Joe Pisapia and Derek Brown as they evaluate 12 high-upside players for the upcoming season and highlight their potential for success or failure in the upcoming season. Is it smart to take Kenneth Walker as a top-12 RB this season? The Pros will tell you!<\/p> <p>Timestamps:<\/p> <p>Introduction - 0:00:01<br \/> Breece Hall - 0:00:39<br \/> Ken Walker - 0:02:52<br \/> Travis Etienne - 0:06:06<b","url":"http:\/\/podcast.fantasypros.com\/risk-vs-reward-are-we-taking-these-12-high-upside-players-ep-1072","published":"2023-05-10 10:00:00","timestamp":1683712800,"duration":"31:29","author":"FantasyPros Football Podcast","author_url":"https:\/\/podcasts.apple.com\/us\/podcast\/fantasypros-fantasy-football-podcast\/id1138942145?mt=2&ls=1","full_img":"\/\/images.fantasypros.com\/images\/logos\/fp-football-podcast-500x500.jpg","stars":"5","ratings":"8,200"},{"content_sport":"MLB","title":"MLB: Leading Off May 9th, 2023 (Ep. 665)","content":"You're sending what in a jar? Joe and Welsh talk Shane-O-Mac, Keller, injuries, more prospects up, plus PrizePicks, DFS and best bets.\n\nTimestamps:\nIntro - 0:03:01\nZac Gallen - 0:02:12\nHow Much Longer with Jordan Walker or Taj Bradley - ...
# </script>
# <podcast-episodes></podcast-episodes><div class="ad-300 js-ad-slot side-content__ad"> <div id="div-gpt-ad-1349068144086-11" style="width:300px;">
# <script defer="" type="text/javascript">
# googletag.cmd.push(function() {
# googletag.display('div-gpt-ad-1349068144086-11');
#  });
# </script>
# </div>
# </div>
# <!--
# <premium-offers></premium-offers>
# <player-news></player-news>
# <consensus-rankings class="consensus-rankings-block--sport-landing-page"></consensus-rankings>
# <podcast-episodes></podcast-episodes>
# <who-should-i-start class="who-should-i-start-block"></who-should-i-start>
# <product-updates v-if="blogData" :blog-data="blogData"></product-updates>
#  --> </div>
# <div class="ad-300 ad-mobile">
# <div id="div-gpt-ad-1614797874628-0" style="width:300px;">
# <script defer="" type="text/javascript">
# googletag.cmd.push(function() {
# if (window.innerWidth <= 730) {
# googletag.display('div-gpt-ad-1614797874628-0');
# }
#  });
# </script>
# </div>
# </div>
# </div> <!-- /.side-content -->
# <script>
#         var pageSport = "NFL".toLowerCase();
#     </script>
# </div> <!-- /.main-content-wrap -->
# </div>]
# []

# %%
# Making a GET request
r = requests.get('https://www.fantasypros.com/nfl/rankings/ppr-cheatsheets.php')

# check status code for response received
# success code - 200
print(r)
 
# Parsing the HTML
soup = bs4.BeautifulSoup(r.content, 'html.parser')
# print(soup.prettify())

# print([tag.name for tag in soup.find_all()])

content = soup.find_all('table', id='ranking_table')
print(content)
# Out:
# <Response [200]>
# []

# %%
import requests
from bs4 import BeautifulSoup
from bs4 import Comment
import pandas as pd


url = 'https://www.fantasypros.com/nfl/rankings/ppr-cheatsheets.php'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

comments = soup.find_all(string=lambda text: isinstance(text, Comment))

tables = []
for each in comments:
    if 'table' in each:
        try:
            tables.append(pd.read_html(each)[0])
        except:
            continue
